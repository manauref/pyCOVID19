# %%
# This notebook looks at covid-19 data from the JHU website
# data can downloaded by running the following command
#
#     git clone https://github.com/CSSEGISandData/COVID-19.git
#
# Written by Tony Qian (5 April 2020)

# %%
# Triple comments '###' invite user action 
#      e.g. date range, states, smoothing intervals
#
# download pandas with 
#     pip3 install pandas
#
# paths assumes ipynb runs from directory that contains git repository
#     modify as necessary

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib notebook

# %%
# load data by location
path = 'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/'
file = '04-04-2020.csv'

data = pd.read_csv(path+file)

# %%
# load data by time
path2 = 'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'
file2 = 'time_series_covid19_confirmed_US.csv'

data2 = pd.read_csv(path2+file2)

# %%
### Choose Date Range ###
start = '3/1/20'
end   = '4/4/20'

df0 = data2.groupby('Province_State').sum()  # combines county level data by State
df1 = df0.loc[:,start:end]                   # earliest date '1/22/20' 
df1
# Out:
#                           3/1/20  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  \
# Province_State
# Alabama                        0       0       0       0       0       0
# Alaska                         0       0       0       0       0       0
# American Samoa                 0       0       0       0       0       0
# Arizona                        1       1       1       1       1       2
# Arkansas                       0       0       0       0       0       0
# California                    12      21      25      35      51      59
# Colorado                       0       0       0       0       0       3
# Connecticut                    0       0       0       0       0       0
# Delaware                       0       0       0       0       0       0
# Diamond Princess               0       0       0       0       0       0
# District of Columbia           0       0       0       0       0       0
# Florida                        0       1       2       2       3       3
# Georgia                        0       0       2       2       2       3
# Grand Princess                 0       0       0       0       0       0
# Guam                           0       0       0       0       0       0
# Hawaii                         0       0       0       0       0       0
# Idaho                          0       0       0       0       0       0
# Illinois                       3       4       4       4       5       5
# Indiana                        0       0       0       0       0       1
# Iowa                           0       0       0       0       0       0
# Kansas                         0       0       0       0       0       0
# Kentucky                       0       0       0       0       0       1
# Louisiana                      0       0       0       0       0       0
# Maine                          0       0       0       0       0       0
# Maryland                       0       0       0       0       0       3
# Massachusetts                  1       1       2       2       2       6
# Michigan                       0       0       0       0       0       0
# Minnesota                      0       0       0       0       0       1
# Mississippi                    0       0       0       0       0       0
# Missouri                       0       0       0       0       0       0
# Montana                        0       0       0       0       0       0
# Nebraska                       0       0       0       0       0       1
# Nevada                         0       0       0       0       1       2
# New Hampshire                  0       1       2       2       2       2
# New Jersey                     0       0       0       0       2       2
# New Mexico                     0       0       0       0       0       0
# New York                       0       1       2      11      23      31
# North Carolina                 0       0       1       1       1       2
# North Dakota                   0       0       0       0       0       0
# Northern Mariana Islands       0       0       0       0       0       0
# Ohio                           0       0       0       0       0       0
# Oklahoma                       0       0       0       0       0       0
# Oregon                         1       3       3       3       3       3
# Pennsylvania                   0       0       0       0       0       2
# Puerto Rico                    0       0       0       0       0       0
# Rhode Island                   1       2       2       2       2       2
# South Carolina                 0       0       0       0       0       0
# South Dakota                   0       0       0       0       0       0
# Tennessee                      0       0       0       0       1       1
# Texas                          0       0       0       0       3       4
# Utah                           0       0       0       0       0       0
# Vermont                        0       0       0       0       0       0
# Virgin Islands                 0       0       0       0       0       0
# Virginia                       0       0       0       0       0       0
# Washington                    11      18      27      39      70      78
# West Virginia                  0       0       0       0       0       0
# Wisconsin                      0       0       0       0       0       0
# Wyoming                        0       0       0       0       0       0
#
#                           3/7/20  3/8/20  3/9/20  3/10/20  ...  3/26/20  \
# Province_State                                             ...
# Alabama                        0       0       0        0  ...      517
# Alaska                         0       0       0        0  ...       56
# American Samoa                 0       0       0        0  ...        0
# Arizona                        4       4       4        6  ...      508
# Arkansas                       0       0       0        0  ...      335
# California                    81      95     101      144  ...     3899
# Colorado                       7       7       7       14  ...     1430
# Connecticut                    0       0       0        1  ...     1012
# Delaware                       0       0       0        0  ...      130
# Diamond Princess               0       0       0        0  ...       49
# District of Columbia           0       0       0        0  ...      231
# Florida                        7      10      13       15  ...     2357
# Georgia                        5       5      10       17  ...     1525
# Grand Princess                 0       0       0        0  ...       28
# Guam                           0       0       0        0  ...       45
# Hawaii                         1       1       1        3  ...       95
# Idaho                          0       0       0        0  ...      146
# Illinois                       6       7       7       12  ...     2538
# Indiana                        1       2       3        6  ...      645
# Iowa                           0       0       3        8  ...      179
# Kansas                         0       1       1        1  ...      172
# Kentucky                       1       1       4        5  ...      247
# Louisiana                      0       0       0        0  ...     2304
# Maine                          0       0       0        0  ...      155
# Maryland                       3       5       5        8  ...      583
# Massachusetts                  6      22      22       41  ...     2417
# Michigan                       0       0       0        0  ...     2845
# Minnesota                      1       1       2        2  ...      344
# Mississippi                    0       0       0        0  ...      485
# Missouri                       0       1       1        1  ...      520
# Montana                        0       0       0        0  ...       90
# Nebraska                       1       1       3        3  ...       74
# Nevada                         2       4       4        4  ...      420
# New Hampshire                  2       4       4        4  ...      137
# New Jersey                     4       5       5       15  ...     6876
# New Mexico                     0       0       0        0  ...      113
# New York                      76     106     142      150  ...    37877
# North Carolina                 2       2       2        7  ...      738
# North Dakota                   0       0       0        0  ...       51
# Northern Mariana Islands       0       0       0        0  ...        0
# Ohio                           0       0       0        3  ...      868
# Oklahoma                       1       1       1        2  ...      248
# Oregon                         6      14      14       14  ...      316
# Pennsylvania                   2       6       7       12  ...     1795
# Puerto Rico                    0       0       0        0  ...       64
# Rhode Island                   3       3       3        3  ...      165
# South Carolina                 2       2       3        7  ...      424
# South Dakota                   0       0       0        0  ...       46
# Tennessee                      1       3       3        3  ...     1097
# Texas                          8      11      13       16  ...     1563
# Utah                           1       1       1        2  ...      396
# Vermont                        0       1       1        1  ...      158
# Virgin Islands                 0       0       0        0  ...       17
# Virginia                       0       2       2        8  ...      466
# Washington                   102     122     122      167  ...     3207
# West Virginia                  0       0       0        0  ...       52
# Wisconsin                      0       0       0        3  ...      728
# Wyoming                        0       0       0        0  ...       53
#
#                           3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  \
# Province_State
# Alabama                       587      694      825      899      987    1060
# Alaska                         58       85      102      114      119     132
# American Samoa                  0        0        0        0        0       0
# Arizona                       665      773      919     1157     1289    1530
# Arkansas                      381      409      426      473      523     584
# California                   4657     5095     5852     7138     8210    9399
# Colorado                     1433     1740     2307     2311     2966    2982
# Connecticut                  1291     1524     1993     2571     3128    3557
# Delaware                      163      214      232      264      319     368
# Diamond Princess               49       49       49       49       49      49
# District of Columbia          271      304      342      401      495     586
# Florida                      2900     3763     4246     5473     6741    6956
# Georgia                      2000     2366     2651     2808     3929    4638
# Grand Princess                 28      103      103      103      103     103
# Guam                           51       55       56       58       69      77
# Hawaii                        106      149      149      175      204     224
# Idaho                         205      234      281      340      515     566
# Illinois                     3024     3491     4596     5056     5994    6980
# Indiana                       979     1233     1513     1786     2158    2564
# Iowa                          235      298      336      424      497     547
# Kansas                        206      266      330      372      434     485
# West Virginia                216     237     282
# Wisconsin                   1748    2012    2030
# Wyoming                      150     162     187
#
# [58 rows x 35 columns]

# %%
### Choose any states ###
states = sorted(['New Jersey','New York', 'Florida', 'California'])

df2 = df1.loc[states,:]

# %%
df2.transpose().plot(style='.',figsize=(8,4))

plt.ylabel('count')
plt.title('Case Count')
plt.grid()

df2.transpose().plot(style='.',figsize=(8,4))

plt.ylabel('count')
plt.yscale('log')
plt.title('Case Count')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
dates = df2.columns

arr = df2.to_numpy()
N = len(arr)

# %%
# configures x axis for plotting dates
def set_dates(dates,M):
    plt.gcf().autofmt_xdate()
    ax = plt.gca()

    ax.set_xticks(dates,minor=True)
    ax.set_xticks(dates[::M])

    # And a corresponding grid
    ax.grid(which='major')

# %%
# smooths (derivatives) by averages M points to the left and right (2M + 1 total)
def smooth(arr,n):
    
    N = len(arr)
    out = []
    for j in np.arange(N):
        if (j < n):
            out.append( arr[j] )
        elif (N - j < n):
            out.append( arr[j] )
        else:
            out.append( np.mean(arr[j-n:j+n]))    
            
    
    return np.array(out)

# %%
# compute first derivative, remove one date
first_deriv = np.transpose(arr[:,1:] - arr[:, :-1])
dates1 = dates[1:]

### set first derivative smoothing interval  
M = 2  
smooth_first_deriv = np.array([smooth(first_deriv[:,j], M) for j in range(N)])

# %%
plt.figure(figsize=(8,5))
for j in range(N):
    
    plt.plot(dates1, smooth_first_deriv[j],'C%i.--'%j, label=states[j])
    plt.plot(dates1, first_deriv[:,j],'C%i--'%j, lw='0.5')

plt.legend()
#plt.title('smooth first deriv')
plt.title('rate of cases')
plt.ylabel('new cases per day')
set_dates(dates1,5)


plt.figure(figsize=(8,5))
for j in range(N):
    
    plt.plot(dates1, smooth_first_deriv[j],'C%i.--'%j, label=states[j])
    #plt.plot(dates[1:], first_deriv[:,j],'C%i--'%j, lw='0.5')

plt.legend()
plt.yscale('log')
#plt.title('smooth first deriv')
plt.title('rate of cases')
plt.ylabel('new cases per day')
set_dates(dates1,5)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
# compute second derivative, remove (1+M) dates
arr2 = np.transpose(smooth_first_deriv)[:-M]
second_deriv = arr2[1:] - arr2[:-1]
dates2 = dates1[1:-M]

### set second derivative smoothing interval 
M2 = 3 
smooth_second_deriv = np.array([smooth(second_deriv[:,j], M2) for j in range(N)])

# %%
plt.figure(figsize=(8,5))

for j in range(N):
    
    plt.plot(dates2, second_deriv[:,j],'C%i--'%j, lw='0.5')
    plt.plot(dates2[:-M2], smooth_second_deriv[j,:-M2],'C%i.--'%j, label=states[j])

plt.legend()
#plt.title('smooth second deriv')
plt.title('rate of new cases')
plt.ylabel('change in new cases per day')

set_dates(dates2,5)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
norm2 = smooth_second_deriv / (smooth_first_deriv[:,1:-M] + 1)

### set normalized second derivative smoothing interval 
M3 = 2 
smooth_norm2 = np.array([smooth(norm2[j], M3) for j in range(N)])

# %%
plt.figure(figsize=(8,5))
for j in range(N):
    #plt.plot(dates2[5:], norm2[j,5:], 'C%i--'%j, lw=0.5)
    plt.plot(dates2[5:], smooth_norm2[j,5:], 'C%i.--'%j, label=states[j])
    
#plt.title('normalized second deriv (smoothed)')
plt.title('percentage of new cases')
plt.ylabel('change in new cases / new cases')
    
plt.legend()

set_dates(dates2[5:],5)
# Out:
# <img src="data:image/png;base64,..." width="800">
